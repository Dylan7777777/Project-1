# %%
#Dependencies
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns
import random
import requests
import json
import hvplot.pandas
from config import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#Read the clean csv file from the Output folder
clean_data = pd.read_csv("../Output/clean_realtor_data.csv")
clean_data = clean_data.drop("STATUS", axis=1)
clean_data = clean_data.drop("Unnamed: 0", axis=1)
clean_data.reset_index()
# Out:
#       index       PRICE   BED  BATH  ACRE LOT  \
# 0         0    149900.0   1.0   1.0      0.26
# 1         1    180000.0   2.0   2.0      0.24
# 2         2     90000.0   2.0   1.0      0.07
# 3         3  10000000.0   6.0   5.0      0.12
# 4         4    600000.0   6.0   5.0      0.10
# ...     ...         ...   ...   ...       ...
# 6298   6298    191000.0   3.0   1.0      0.10
# 6299   6299    210000.0   3.0   1.0      0.04
# 6300   6300   4649000.0  28.0  22.0      0.15
# 6301   6301    235000.0   2.0   2.0      0.14
# 6302   6302   1095000.0   5.0   5.0      0.24
#
#                                            FULL ADDRESS  \
# 0              Bo Espinal Carr # 442, Aguada, PR, 00602
# 1                            4417 Br, Aguada, PR, 00602
# 2      A-18 Condominio Los Almendros, Aguada, PR, 00602
# 3      441 Bo Carrizal Km 2 6 Unit 4, Aguada, PR, 00602
# 4                                 Pr, Aguada, PR, 00602
# ...                                                 ...
# ...

# %%
#Create a function to fix zip_code from float and 3 digits to string 
def fix_zip(series):
    return series.astype(str).str.extract('(\d+)', expand=False).str.zfill(5)

clean_data["ZIP Code"] = fix_zip(clean_data["ZIP"])
del clean_data["ZIP"]
clean_data.head()
# Out:
#         PRICE  BED  BATH  ACRE LOT  \
# 0    149900.0  1.0   1.0      0.26
# 1    180000.0  2.0   2.0      0.24
# 2     90000.0  2.0   1.0      0.07
# 3  10000000.0  6.0   5.0      0.12
# 4    600000.0  6.0   5.0      0.10
#
#                                        FULL ADDRESS  \
# 0          Bo Espinal Carr # 442, Aguada, PR, 00602
# 1                        4417 Br, Aguada, PR, 00602
# 2  A-18 Condominio Los Almendros, Aguada, PR, 00602
# 3  441 Bo Carrizal Km 2 6 Unit 4, Aguada, PR, 00602
# 4                             Pr, Aguada, PR, 00602
#
#                           STREET    CITY        STATE  HOUSE SIZE ZIP Code
# 0          Bo Espinal Carr # 442  Aguada  Puerto Rico      2100.0    00602
# 1                        4417 Br  Aguada  Puerto Rico      1138.0    00602
# 2  A-18 Condominio Los Almendros  Aguada  Puerto Rico       813.0    00602
# 3  441 Bo Carrizal Km 2 6 Unit 4  Aguada  Puerto Rico      6000.0    00602
# ...

# %%
#Sorting the top 10 cheapest homes in this Eastern Region Real Estate Dataset
cheap_zip = clean_data.sort_values("PRICE")
cheap_zip.head(10)
# Out:
#         PRICE  BED  BATH  ACRE LOT  \
# 5497  16000.0  2.0   1.0      0.04
# 5861  21000.0  2.0   2.0      0.00
# 4770  24888.0  1.0   1.0      0.10
# 6272  25000.0  2.0   2.0      0.09
# 1058  26000.0  3.0   1.0      0.14
# 1057  26500.0  6.0   1.0      1.60
# 4971  28000.0  1.0   1.0      0.07
# 213   31000.0  3.0   2.0      0.05
# 5960  34900.0  3.0   2.0      0.15
# 5714  35900.0  3.0   1.0      2.25
#
#                                            FULL ADDRESS  \
# 5497  1405 Farrell Ave Trlr 327, Cherry Hill, NJ, 08002
# 5861              8 Cedarwood Dr, Pittsgrove, NJ, 08318
# 4770                 114 Mallard Ln, Shohola, PA, 18458
# 6272               28 Dogwood Ln, Pittsgrove, NJ, 08318
# 1058                8 Lincoln St, Brownville, ME, 04414
# 1057         58 Stickney Hill Rd, Brownville, ME, 04414
# 4971                   145 Aztec Dr, Shohola, PA, 18458
# 213         Mariano Martorel Lot 20, Yabucoa, PR, 00767
# 5960                   329 Keasbey St, Salem, NJ, 08079
# ...

# %%
chp_df=cheap_zip.head(10)
chp_df
# Out:
#         PRICE  BED  BATH  ACRE LOT  \
# 5497  16000.0  2.0   1.0      0.04
# 5861  21000.0  2.0   2.0      0.00
# 4770  24888.0  1.0   1.0      0.10
# 6272  25000.0  2.0   2.0      0.09
# 1058  26000.0  3.0   1.0      0.14
# 1057  26500.0  6.0   1.0      1.60
# 4971  28000.0  1.0   1.0      0.07
# 213   31000.0  3.0   2.0      0.05
# 5960  34900.0  3.0   2.0      0.15
# 5714  35900.0  3.0   1.0      2.25
#
#                                            FULL ADDRESS  \
# 5497  1405 Farrell Ave Trlr 327, Cherry Hill, NJ, 08002
# 5861              8 Cedarwood Dr, Pittsgrove, NJ, 08318
# 4770                 114 Mallard Ln, Shohola, PA, 18458
# 6272               28 Dogwood Ln, Pittsgrove, NJ, 08318
# 1058                8 Lincoln St, Brownville, ME, 04414
# 1057         58 Stickney Hill Rd, Brownville, ME, 04414
# 4971                   145 Aztec Dr, Shohola, PA, 18458
# 213         Mariano Martorel Lot 20, Yabucoa, PR, 00767
# 5960                   329 Keasbey St, Salem, NJ, 08079
# ...

# %%
#Number of properties for sale by state
state_count = clean_data["STATE"].value_counts()
state_count
# Out:
# New York          1993
# New Jersey        1543
# Connecticut       1035
# Puerto Rico        454
# Maine              428
# Pennsylvania       330
# Delaware           251
# Rhode Island       199
# Massachusetts       62
# New Hampshire        4
# Vermont              3
# Virgin Islands       1
# Name: STATE, dtype: int64

# %%
#Sorting the Data by one state in this case New York to see if we can make sense of the data
ny_data = clean_data.loc[clean_data["STATE"] == "New York"]
ny_data.head()
# Out:
#         PRICE  BED  BATH  ACRE LOT                               FULL ADDRESS  \
# 456   40000.0  2.0   1.0      0.20  423 Morey Park Hill Rd, Nassau, NY, 12123
# 457  429900.0  4.0   3.0      2.15        43 Plum Tree Dr, Valatie, NY, 12184
# 458  299900.0  3.0   1.0      0.32        14 Evelyn Ln, Niverville, NY, 12130
# 459  299900.0  3.0   1.0      0.32        14 Evelyn Ln, Kinderhook, NY, 12106
# 461  105000.0  4.0   2.0     22.52        71 Lords Hill Rd, Nassau, NY, 12123
#
#                      STREET        CITY     STATE  HOUSE SIZE ZIP Code
# 456  423 Morey Park Hill Rd      Nassau  New York       690.0    12123
# 457         43 Plum Tree Dr     Valatie  New York      2248.0    12184
# 458            14 Evelyn Ln  Niverville  New York      1608.0    12130
# 459            14 Evelyn Ln  Kinderhook  New York      1608.0    12106
# 461        71 Lords Hill Rd      Nassau  New York      1795.0    12123

# %%
#Sorting the Data by one state in this case New Jersey to see if we can make sense of the data
nj_data = clean_data.loc[clean_data["STATE"] == "New Jersey"]
nj_data.head()
# Out:
#           PRICE  BED  BATH  ACRE LOT  \
# 2678   399000.0  3.0   3.0      0.06
# 2713  1495000.0  3.0   2.0      0.12
# 2714   155000.0  1.0   1.0      0.04
# 2743   459900.0  3.0   2.0      0.08
# 2744   249000.0  3.0   2.0      4.75
#
#                                        FULL ADDRESS                    STREET  \
# 2678             1188 Rahway Ave, Avenel, NJ, 07001           1188 Rahway Ave
# 2713              192 W 31st St, Bayonne, NJ, 07002             192 W 31st St
# 2714         15 Broadway Apt 43, Bayonne, NJ, 07002        15 Broadway Apt 43
# 2743      387 Lawton Ave, Cliffside Park, NJ, 07010            387 Lawton Ave
# 2744  2200 N Central Rd Apt 5L, Fort Lee, NJ, 07024  2200 N Central Rd Apt 5L
#
#                 CITY       STATE  HOUSE SIZE ZIP Code
# 2678          Avenel  New Jersey      1476.0    07001
# 2713         Bayonne  New Jersey      1104.0    07002
# 2714         Bayonne  New Jersey       400.0    07002
# ...

# %%
#Sorting the Data by one state in this case Connecticut to see if we can make sense of the data
ct_data = clean_data.loc[clean_data["STATE"] == "Connecticut"]
ct_data.head()
# Out:
#         PRICE  BED  BATH  ACRE LOT                            FULL ADDRESS  \
# 455  279900.0  3.0   2.0      0.35   11 Schenone Ct, Plainville, CT, 06062
# 527  994900.0  4.0   4.0      2.01   14 Laureate Dr, Middletown, CT, 06457
# 528  340000.0  4.0   3.0      1.20          127 Main St, Durham, CT, 06422
# 529  409900.0  8.0   3.0      0.22  254 Corbin Ave, New Britain, CT, 06052
# 530  349900.0  3.0   3.0      0.50    63 Lenti Ter, Glastonbury, CT, 06033
#
#              STREET         CITY        STATE  HOUSE SIZE ZIP Code
# 455  11 Schenone Ct   Plainville  Connecticut      1004.0    06062
# 527  14 Laureate Dr   Middletown  Connecticut      4952.0    06457
# 528     127 Main St       Durham  Connecticut      3213.0    06422
# 529  254 Corbin Ave  New Britain  Connecticut      2913.0    06052
# 530    63 Lenti Ter  Glastonbury  Connecticut      1300.0    06033

# %%
#Sorting the Data by one state in this case Puerto Rico to see if we can make sense of the data
pr_data = clean_data.loc[clean_data["STATE"] == "Puerto Rico"]
pr_data.head()
# Out:
#         PRICE  BED  BATH  ACRE LOT  \
# 0    149900.0  1.0   1.0      0.26
# 1    180000.0  2.0   2.0      0.24
# 2     90000.0  2.0   1.0      0.07
# 3  10000000.0  6.0   5.0      0.12
# 4    600000.0  6.0   5.0      0.10
#
#                                        FULL ADDRESS  \
# 0          Bo Espinal Carr # 442, Aguada, PR, 00602
# 1                        4417 Br, Aguada, PR, 00602
# 2  A-18 Condominio Los Almendros, Aguada, PR, 00602
# 3  441 Bo Carrizal Km 2 6 Unit 4, Aguada, PR, 00602
# 4                             Pr, Aguada, PR, 00602
#
#                           STREET    CITY        STATE  HOUSE SIZE ZIP Code
# 0          Bo Espinal Carr # 442  Aguada  Puerto Rico      2100.0    00602
# 1                        4417 Br  Aguada  Puerto Rico      1138.0    00602
# 2  A-18 Condominio Los Almendros  Aguada  Puerto Rico       813.0    00602
# 3  441 Bo Carrizal Km 2 6 Unit 4  Aguada  Puerto Rico      6000.0    00602
# ...

# %%
#Sorting the Data by one state in this case Maine to see if we can make sense of the data
me_data = clean_data.loc[clean_data["STATE"] == "Maine"]
me_data.head()
# Out:
#         PRICE  BED  BATH  ACRE LOT                              FULL ADDRESS  \
# 838  399900.0  3.0   2.0      0.64           37 Morse St, Berwick, ME, 03901
# 839  415000.0  4.0   2.0      1.26          62 School St, Berwick, ME, 03901
# 840  489000.0  3.0   3.0      2.07         8 Callahan Ln, Berwick, ME, 03901
# 841  669900.0  3.0   2.0     10.84            New Dam Rd, Berwick, ME, 03901
# 842  299900.0  2.0   1.0      0.86  156 Lebanon Rd, North Berwick, ME, 03906
#
#              STREET           CITY  STATE  HOUSE SIZE ZIP Code
# 838     37 Morse St        Berwick  Maine      2356.0    03901
# 839    62 School St        Berwick  Maine      2000.0    03901
# 840   8 Callahan Ln        Berwick  Maine      2160.0    03901
# 841      New Dam Rd        Berwick  Maine      1340.0    03901
# 842  156 Lebanon Rd  North Berwick  Maine       884.0    03906

# %%
#Sorting the Data by one state in this case Pennsylvania to see if we can make sense of the data
pa_data = clean_data.loc[clean_data["STATE"] == "Pennsylvania"]
pa_data.head()
# Out:
#          PRICE  BED  BATH  ACRE LOT  \
# 4656  279900.0  3.0   3.0      1.14
# 4657  129900.0  3.0   1.0      0.56
# 4658  160000.0  3.0   1.0      0.22
# 4659  189900.0  2.0   3.0      0.03
# 4660  259900.0  3.0   2.0      0.13
#
#                                            FULL ADDRESS              STREET  \
# 4656  9809 N Delaware Dr, Lower Mt Bethel Township, ...  9809 N Delaware Dr
# 4657             15 Elm St, East Stroudsburg, PA, 18301           15 Elm St
# 4658                    6489 Ann Ave, Bangor, PA, 18013        6489 Ann Ave
# 4659              12 Turtle Way, Stroudsburg, PA, 18360       12 Turtle Way
# 4660    196 Lackawanna Ave, East Stroudsburg, PA, 18301  196 Lackawanna Ave
#
#                           CITY         STATE  HOUSE SIZE ZIP Code
# 4656  Lower Mt Bethel Township  Pennsylvania      1865.0    18013
# 4657          East Stroudsburg  Pennsylvania      1050.0    18301
# 4658                    Bangor  Pennsylvania      1011.0    18013
# ...

# %%
#Sorting the Data by one state in this case Delaware to see if we can make sense of the data
de_data = clean_data.loc[clean_data["STATE"] == "Delaware"]
de_data.head()
# Out:
#          PRICE  BED  BATH  ACRE LOT                            FULL ADDRESS  \
# 5720   68900.0  3.0   1.0      0.11     1115 Gray Ct, New Castle, DE, 19720
# 5723  199900.0  4.0   2.0      0.17  17 Rambleton Dr, New Castle, DE, 19720
# 5726   85000.0  6.0   2.0      0.07     506 E 9th St, Wilmington, DE, 19801
# 5735  150000.0  3.0   2.0      0.40       719 Cardinal Ave, Bear, DE, 19701
# 5740  121000.0  2.0   1.0      0.10     4 Albany Ave, New Castle, DE, 19720
#
#                 STREET        CITY     STATE  HOUSE SIZE ZIP Code
# 5720      1115 Gray Ct  New Castle  Delaware      1275.0    19720
# 5723   17 Rambleton Dr  New Castle  Delaware      2072.0    19720
# 5726      506 E 9th St  Wilmington  Delaware      2525.0    19801
# 5735  719 Cardinal Ave        Bear  Delaware      1975.0    19701
# 5740      4 Albany Ave  New Castle  Delaware       500.0    19720

# %%
#Sorting the Data by one state in this case Rhode Island to see if we can make sense of the data
ri_data = clean_data.loc[clean_data["STATE"] == "Rhode Island"]
ri_data.head()
# Out:
#          PRICE   BED  BATH  ACRE LOT  \
# 625   599000.0   4.0   3.0      2.28
# 626   279900.0   2.0   2.0      2.30
# 627  2495000.0   4.0   4.0      0.92
# 628  7500000.0  31.0  27.0      2.62
# 629   825000.0   2.0   1.0      0.12
#
#                                           FULL ADDRESS  \
# 625                    1 Hana Ln, Hopkinton, RI, 02804
# 626  60 Bay Spring Ave Unit 11A, Barrington, RI, 02806
# 627               0 Rumstick Rd, Barrington, RI, 02806
# 628       359 and 361 High St, Block Island, RI, 02807
# 629         27 High St Unit 4, Block Island, RI, 02807
#
#                          STREET          CITY         STATE  HOUSE SIZE  \
# 625                   1 Hana Ln     Hopkinton  Rhode Island      2332.0
# 626  60 Bay Spring Ave Unit 11A    Barrington  Rhode Island       882.0
# 627               0 Rumstick Rd    Barrington  Rhode Island      4250.0
# 628         359 and 361 High St  Block Island  Rhode Island     22774.0
# ...

# %%
#Sorting the Data by one state in this case Massachusetts to see if we can make sense of the data
ma_data = clean_data.loc[clean_data["STATE"] == "Massachusetts"]
ma_data.head()
# Out:
#          PRICE   BED  BATH  ACRE LOT  \
# 460  1495000.0  11.0   8.0     20.00
# 526   150000.0   5.0   3.0      0.11
# 533  5900000.0   4.0   6.0     44.00
# 570   599900.0   5.0   2.0      0.37
# 571   587877.0   4.0   3.0      0.11
#
#                                           FULL ADDRESS  \
# 460  602-606 Hartsville New Marlborough Rd, New Mar...
# 526       71-73 W Housatonic St, Pittsfield, MA, 01201
# 533          38 Pixley Hl, West Stockbridge, MA, 01266
# 570                  19 Clinton St, Methuen, MA, 01844
# 571                      104 Cliff St, Lynn, MA, 01905
#
#                                     STREET              CITY          STATE  \
# 460  602-606 Hartsville New Marlborough Rd   New Marlborough  Massachusetts
# 526                  71-73 W Housatonic St        Pittsfield  Massachusetts
# 533                           38 Pixley Hl  West Stockbridge  Massachusetts
# 570                          19 Clinton St           Methuen  Massachusetts
# ...

# %%
#scatter plot of Size of House vs price State of New York
x_values = ny_data["HOUSE SIZE"]
y_values = ny_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2000,30000000),fontsize=15,color="red")
plt.title("New York House Price vs Size")
plt.xlabel("Size of House NY")
plt.ylabel("Price of House NY (in $10mln)")
plt.xlim(0,14000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.3014051520078212
# The pvalue is : 2.7455870672958855e-157

# %%
#scatter plot of Size of House vs price State of New Jersey
x_values = nj_data["HOUSE SIZE"]
y_values = nj_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2000,12000000),fontsize=15,color="red")
plt.title("New Jersey House Price vs Size")
plt.xlabel("Size of House NJ")
plt.ylabel("Price of House NJ (in $10mln) ")
plt.xlim(0,14000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.155183830860985
# The pvalue is : 1.9112368397231642e-58

# %%
#scatter plot of Size of House vs price territory of Puerto Rico
x_values = pr_data["HOUSE SIZE"]
y_values = pr_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6500,13500000),fontsize=15,color="red")
plt.title("Puerto Rico House Price vs Size")
plt.xlabel("Size of House Puerto Rico")
plt.ylabel("Price of House Puerto Rico")
plt.xlim(0,14000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.019648074867199574
# The pvalue is : 0.0027604003427820975

# %%
#scatter plot of Size of House vs price territory of Maine
x_values = me_data["HOUSE SIZE"]
y_values = me_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6500,13500000),fontsize=15,color="red")
plt.title("Maine House Size vs Price")
plt.xlabel("Size of House Maine")
plt.ylabel("Price of Maine (in Mln$)")
plt.xlim(0,12000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.1515181987442307
# The pvalue is : 6.195823354619889e-17

# %%
#scatter plot of Size of House vs price territory of Pennsylvania
x_values = pa_data["HOUSE SIZE"]
y_values = pa_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4000,3000000),fontsize=15,color="red")
plt.title("Pennsylvania House Size vs Price")
plt.xlabel("Size of House Pennsylvania")
plt.ylabel("Price of House Pennsylvania (in Mln$)")
plt.xlim(0,12000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.23714826387209942
# The pvalue is : 4.701207176521519e-21

# %%
#scatter plot of Size of House vs price territory of Delaware
x_values = de_data["HOUSE SIZE"]
y_values = de_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1000,500000),fontsize=15,color="red")
plt.title("Delaware House Size vs Price")
plt.xlabel("Size of House Delaware")
plt.ylabel("Price of House Delaware $ ")
plt.xlim(0,5000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.29625513912125717
# The pvalue is : 9.262971787966297e-21

# %%
#scatter plot of Size of House vs price territory of Rhode Island
x_values = ri_data["HOUSE SIZE"]
y_values = ri_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(500,4200000),fontsize=15,color="red")
plt.title("Rhode Island House Size vs Price")
plt.xlabel("Size of House Rhode Island")
plt.ylabel("Price of House Rhode Island (in Mln$)")
plt.xlim(0,10000)
plt.ylim(-10000,5000000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.5446443531993002
# The pvalue is : 1.7054533208432746e-35

# %%
#scatter plot of Size of House vs price territory of Maine
x_values = ma_data["HOUSE SIZE"]
y_values = ma_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4500,2400000),fontsize=15,color="red")
plt.title("Massachusetts House Size vs Price")
plt.xlabel("Size of House Massachusetts")
plt.ylabel("Price of House Massachusetts (in Mln$)")
plt.xlim(0,12000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.16928356712738338
# The pvalue is : 0.0008930668111834536

# %%
#scatter plot of Number of bedrooms vs price State of New York
x_values = ny_data["BED"]
y_values = ny_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,30000000),fontsize=15,color="red")
plt.title("New York No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms NY")
plt.ylabel("Price of the Home (in $10mln)")
plt.xlim(0,30)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.06261939011322772
# The pvalue is : 7.81873292057513e-30

# %%
#scatter plot of Number of bedrooms vs price State of New Jersey
x_values = nj_data["BED"]
y_values = nj_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4,12000000),fontsize=15,color="red")
plt.title("New Jersey No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms NJ")
plt.ylabel("Price of the Home NJ (in $10mln)")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.2335417845241524
# The pvalue is : 4.180649795192259e-91

# %%
#scatter plot of Number of bedrooms vs price State of Connecticut
x_values = ct_data["BED"]
y_values = ct_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(3,22000000),fontsize=15,color="red")
plt.title("Connecticut No of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms CT")
plt.ylabel("Price of the Home CT (in $10mln)")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.27876258026798306
# The pvalue is : 2.336174292208241e-75

# %%
#scatter plot of Number of bedrooms vs price in the territory of Puerto Rico
x_values = pr_data["BED"]
y_values = pr_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,10800000),fontsize=15,color="red")
plt.title("Puerto Rico No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms PR")
plt.ylabel("Price of the Home PR (in $10mln)")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.13003715378191633
# The pvalue is : 2.1780899190998804e-15

# %%
#scatter plot of Number of bedrooms vs price in the territory of Maine
x_values = me_data["BED"]
y_values = me_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,6000000),fontsize=15,color="red")
plt.title("Maine No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms ME")
plt.ylabel("Price of the Home ME (in Mln$)")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.04629328752450909
# The pvalue is : 7.091413348117493e-06

# %%
#scatter plot of Number of bedrooms vs price in the territory of Pennsylvania
x_values = pa_data["BED"]
y_values = pa_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1,3000000),fontsize=15,color="red")
plt.title("Pennsylvannia No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms PA")
plt.ylabel("Price of the Home PA (in Mln$)")
plt.xlim(0,12)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.22120814825401483
# The pvalue is : 1.44498866980578e-19

# %%
#scatter plot of Number of bedrooms vs price in the territory of Delaware
x_values = de_data["BED"]
y_values = de_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,500000),fontsize=15,color="red")
plt.title("Delaware No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms DE")
plt.ylabel("Price of the Home DE")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.04464000353763452
# The pvalue is : 0.0007551414533784906

# %%
#scatter plot of Number of bedrooms vs price in the territory of Massachusetts
x_values = ma_data["BED"]
y_values = ma_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,10800000),fontsize=15,color="red")
plt.title("Massachusetts No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms MA")
plt.ylabel("Price of the Home MA (in $10mln)")
plt.xlim(0,15)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.show()
# Out:
# The r-squared is: 0.03704454784418249
# The pvalue is : 0.13394709892101717

# %%
# Select the relevant columns ('BED', 'HOUSE SIZE', 'ACRE LOT', and 'PRICE') from the DataFrame
selected_columns = clean_data[['BED', 'HOUSE SIZE', 'ACRE LOT', 'PRICE']]

# Sample a smaller subset of the data for visualization (adjust the sample size as needed)
sample_size = 40
random.seed(2)  # For reproducibility
sampled_data = selected_columns.sample(n=sample_size)

# Create a pair plot to visualize the relationships between these variables in the sampled data
sns.pairplot(sampled_data)
plt.suptitle('Pair Plot of Bedrooms, Size, Acres, and Property Price (Sampled Data)', y=1.02)
plt.show()

# %% [markdown]
# ## Q1 How do average property prices vary across different states?

# %%
#Using bar plot to visualize the average property price for each region.
average_price_by_zip = clean_data.groupby('STATE')['PRICE'].mean().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=average_price_by_zip.index, y=average_price_by_zip.values, palette='coolwarm')
plt.xticks(rotation=45, ha='right')
plt.xlabel('STATE')
plt.ylabel('Average Property Price')
plt.title('Fig.1 Average Property Price Across States')
plt.tight_layout()
plt.savefig("../Fig.1 average_property_price.png")
plt.show()

# %% [markdown]
# What is more influential on the overall cost: bedrooms, size, or acres?
#
# To determine the influence of bedrooms, size, and acres on the overall cost,  we can use a correlation matrix and a pair plot. The correlation matrix will show the relationships between these features, and the pair plot will allow us to visualize these relationships graphically.

# %%
#We Use boxplot charts for house prices to visualize mean prices as well as outliers
nine_state = [ny_data["PRICE"],nj_data["PRICE"],ct_data["PRICE"],pr_data["PRICE"],me_data["PRICE"],pa_data["PRICE"],de_data["PRICE"],ri_data["PRICE"],ma_data["PRICE"]]
state=["NY", "NJ", "CT","PR","ME","PA","DE","RI","MA"]

fig, ax = plt.subplots()
outlier_format = dict( color = 'r', marker='o')
ax.boxplot(nine_state , labels=state )
plt.title("Fig.2 Box Plot Chart to Observe Outliers ")
plt.xlabel("States")
plt.ylabel("House Prices (log scale)")
plt.yscale("log")
plt.savefig("../Fig.2 box_plot_states_to_display_outliers.png")
plt.show()

# %% [markdown]
# ## Q2a What is the correlation if any between household features and property prices?

# %%
# Select the relevant columns ('BED', 'HOUSE SIZE', 'ACRE LOT', and 'PRICE') from the DataFrame
selected_columns = clean_data[['BED', 'HOUSE SIZE', 'ACRE LOT', 'PRICE']]

# Calculate the correlation matrix
correlation_matrix = selected_columns.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Fig.3 Correlation Matrix: Bedrooms, Size, Acres, and Price')
plt.savefig("../Fig.3 correlation_matrix_bed_size_acres.png")
plt.show()

# %% [markdown]
# ## Q2b What does the data tell us when doing a deeper dive into specific states?

# %%
#scatter plot of Size of House vs price State of Connecticut
x_values = ct_data["HOUSE SIZE"]
y_values = ct_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2000,35000000),fontsize=14,color="red")
plt.title("Fig.4 Connecticut House Price vs Size")
plt.xlabel("Size of House Connecticut")
plt.ylabel("Price of House Connecticut (in $10 mln)")
plt.xlim(0,20000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.savefig("../Fig.4 price_vs_size_ct.png")
plt.show()
# Out:
# The r-squared is: 0.6319639467202537
# The pvalue is : 1.890462370956032e-226

# %%
#scatter plot of Number of bedrooms vs price in the territory of Rhode Island
x_values = ri_data["BED"]
y_values = ri_data["PRICE"]
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = "+str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,5200000),fontsize=15,color="red")
plt.title("Fig.5 Rhode Island No. of Bedrooms vs Price")
plt.xlabel("Number of Bedrooms RI")
plt.ylabel("Price of the Home RI (in Mln$)")
plt.xlim(0,13)
plt.ylim(-10000,6000000)
print(f"The r-squared is: {rvalue**2}")
print(f"The pvalue is : {pvalue}")
plt.savefig("../Fig.5 rhodeisland_bedroom_vs_price.png")
plt.show()
# Out:
# The r-squared is: 0.33155329042114523
# The pvalue is : 5.736712651390267e-19

# %% [markdown]
# The correlation matrix is represented by a heatmap, where each cell shows the correlation coefficient between two variables. The correlation coefficient ranges from -1 to 1, where -1 indicates a perfect negative correlation, 1 indicates a perfect positive correlation, and 0 indicates no correlation. By examining the heatmap, you can see the strength and direction of the relationships between bedrooms, size, acres, and property price.

# %% [markdown]
# ## Q3 Are there any other factors that could be driving house prices?
# ### Lets Drill into location of listings in Massachusetts

# %%
#Insert columns for Latitude and Longitude in the Massachusetts DataFrame
ma_data["Lat"]=""
ma_data["Lon"]=""
ma_data.head()
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_23152\1570000417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ma_data["Lat"]=""
# C:\Users\dylan\AppData\Local\Temp\ipykernel_23152\1570000417.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ma_data["Lon"]=""
#          PRICE   BED  BATH  ACRE LOT  \
# 460  1495000.0  11.0   8.0     20.00
# 526   150000.0   5.0   3.0      0.11
# 533  5900000.0   4.0   6.0     44.00
# 570   599900.0   5.0   2.0      0.37
# ...

# %%
#Define the API parameters
params = {"apiKey":geoapify_key,"format":"json"}

#Set the base URL
base_url = "https://api.geoapify.com/v1/geocode/search?"

# %%
# loop thgough the Massachusetts dataframe and search coordinates for each zip code
for index, row in ma_data.iterrows():
    
    city=row["CITY"]+", Massachusetts, United States"
    
    params["text"] = f"{city}"
    
    response=requests.get(base_url, params=params)
    
    data=response.json()
    
    
    lon = data["results"][0]["lon"]
    lat = data["results"][0]["lat"]
    
    ma_data.loc[index,"Lat"] = lat
    ma_data.loc[index,"Lon"] = lon
    
ma_data.head()
# Out:
#          PRICE   BED  BATH  ACRE LOT  \
# 460  1495000.0  11.0   8.0     20.00
# 526   150000.0   5.0   3.0      0.11
# 533  5900000.0   4.0   6.0     44.00
# 570   599900.0   5.0   2.0      0.37
# 571   587877.0   4.0   3.0      0.11
#
#                                           FULL ADDRESS  \
# 460  602-606 Hartsville New Marlborough Rd, New Mar...
# 526       71-73 W Housatonic St, Pittsfield, MA, 01201
# 533          38 Pixley Hl, West Stockbridge, MA, 01266
# 570                  19 Clinton St, Methuen, MA, 01844
# 571                      104 Cliff St, Lynn, MA, 01905
#
#                                     STREET              CITY          STATE  \
# 460  602-606 Hartsville New Marlborough Rd   New Marlborough  Massachusetts
# 526                  71-73 W Housatonic St        Pittsfield  Massachusetts
# 533                           38 Pixley Hl  West Stockbridge  Massachusetts
# 570                          19 Clinton St           Methuen  Massachusetts
# ...

# %%
#plot a scatter plot of the latitude and longitude of Pennsylvania data color the dots based on house price
plt.scatter(ma_data["Lon"], ma_data["Lat"],c=ma_data["PRICE"])
clb=plt.colorbar()
plt.title("Fig.6 Massacusetts Coordinates of Listings vs Price")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
clb.set_label("Price of home")
plt.savefig("../Fig.6 massachusetts_lat_lon_vs_price.png")
plt.show()

# %% [markdown]
# ### Massachusetts Map with listings size of plots adjusted by price

# %%
#Potting Massachusetts houses for sale on a map diffrenciating by price

map_plot_ma = ma_data.hvplot.points("Lon","Lat",geo=True,tiles="OSM",frame_width = 725,frame_height=500,size="PRICE",scale=.01,color="CITY")
hvplot.save(map_plot_ma,"../Fig.7 massachusetts_map_listings_by_price.png")
map_plot_ma
# Out:
# C:\Users\dylan\Desktop\Anaconda\envs\dev\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1018', ...)
# WARNING:bokeh.io.export:There were browser warnings and/or errors that may have affected your export
# WARNING:bokeh.io.export:file:///C:/Data_Analytics/Project-1/Project_1/bokehvuartf81.html - [.WebGL-0000661400279C00]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels
# WARNING:bokeh.io.export:file:///C:/Data_Analytics/Project-1/Project_1/bokehvuartf81.html - [.WebGL-0000661400279C00]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels
# ...

# %% [markdown]
# ## Bonus Question
# ### Are you curious about where the most expensive listings are located?
# ### The dataframe below lists the top 10 most expensive listings in this dataset

# %%
#Sorting the top 10 most expensive homes by zip codes in this Eastern Region Real Estate Dataset
expensive_zip = clean_data.sort_values("PRICE",ascending=False)
exp_df = expensive_zip.head(10)
exp_df
# Out:
#            PRICE   BED  BATH  ACRE LOT  \
# 3833  49900000.0   5.0   7.0      3.43
# 2985  45000000.0  16.0  21.0      0.10
# 2813  42500000.0   5.0   8.0      0.54
# 2255  39000000.0   8.0  13.0      8.23
# 2684  34990000.0   7.0  13.0      5.31
# 2599  32000000.0   6.0  12.0     10.00
# 2382  30000000.0  11.0  11.0      6.38
# 2508  29997000.0   7.0  13.0     17.20
# 3826  29975000.0   7.0   9.0      0.05
# 2550  28000000.0   5.0   9.0     87.00
#
#                                          FULL ADDRESS                  STREET  \
# 3833  25 Columbus Cir Ph 80, New York City, NY, 10019   25 Columbus Cir Ph 80
# 2985     217-219 W Broadway, New York City, NY, 10013      217-219 W Broadway
# 2813  293 Lafayette St Ph 1, New York City, NY, 10012   293 Lafayette St Ph 1
# 2255               555 Lake Ave, Greenwich, CT, 06830            555 Lake Ave
# 2684                15 Dairy Rd, Greenwich, CT, 06830             15 Dairy Rd
# ...

# %%
#extract latitude and Longitude
exp_df["Lat"]=""
exp_df["Lon"]=""
exp_df.head()
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_23152\2622785132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df["Lat"]=""
# C:\Users\dylan\AppData\Local\Temp\ipykernel_23152\2622785132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df["Lon"]=""
#            PRICE   BED  BATH  ACRE LOT  \
# 3833  49900000.0   5.0   7.0      3.43
# 2985  45000000.0  16.0  21.0      0.10
# 2813  42500000.0   5.0   8.0      0.54
# 2255  39000000.0   8.0  13.0      8.23
# ...

# %%
# loop thgough the connecticut dataframe and search coordinates for each zip code
for index, row in exp_df.iterrows():
    
    city=row["CITY"]+", United States"
    #Add params City
    params["text"] = f"{city}"
    #get url by adding parameters to the base url
    response=requests.get(base_url, params=params)
    #converting response to json
    data=response.json()
    
    
    lon = data["results"][0]["lon"]
    lat = data["results"][0]["lat"]
    
    exp_df.loc[index,"Lat"] = lat
    exp_df.loc[index,"Lon"] = lon
    
exp_df.head()
# Out:
#            PRICE   BED  BATH  ACRE LOT  \
# 3833  49900000.0   5.0   7.0      3.43
# 2985  45000000.0  16.0  21.0      0.10
# 2813  42500000.0   5.0   8.0      0.54
# 2255  39000000.0   8.0  13.0      8.23
# 2684  34990000.0   7.0  13.0      5.31
#
#                                          FULL ADDRESS                 STREET  \
# 3833  25 Columbus Cir Ph 80, New York City, NY, 10019  25 Columbus Cir Ph 80
# 2985     217-219 W Broadway, New York City, NY, 10013     217-219 W Broadway
# 2813  293 Lafayette St Ph 1, New York City, NY, 10012  293 Lafayette St Ph 1
# 2255               555 Lake Ave, Greenwich, CT, 06830           555 Lake Ave
# 2684                15 Dairy Rd, Greenwich, CT, 06830            15 Dairy Rd
#
#                CITY        STATE  HOUSE SIZE ZIP Code        Lat        Lon
# 3833  New York City     New York      8274.0    10019  40.712728 -74.006015
# 2985  New York City     New York     29363.0    10013  40.712728 -74.006015
# ...

# %% [markdown]
# ### Top 10 most expensive listings in this dataset

# %%
#Potting Most expensive houses for sale on a map diffrenciating by price

map_plot_exp = exp_df.hvplot.points("Lon","Lat",geo=True,tiles="OSM",frame_width = 725,frame_height=500,size="PRICE",scale=.003,color="CITY")
hvplot.save(map_plot_exp,"../Fig.9 expensive_map_listings_by_price.png")
map_plot_exp
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1380', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (CITY,PRICE)
